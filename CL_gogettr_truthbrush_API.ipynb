# %% [markdown]
# <center>
# <img src="https://laelgelcpublic.s3.sa-east-1.amazonaws.com/lael_50_years_narrow_white.png.no_years.400px_96dpi.png" width="300" alt="LAEL 50 years logo">
# <h3>APPLIED LINGUISTICS GRADUATE PROGRAMME (LAEL)</h3>
# </center>
# <hr>

# %% [markdown]
# # `GoGettr` - API client for GETTR
# # `Truthbrush` - API client for Truth Social

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# ### `GoGettr` and `Truthbrush`

# %% [markdown]
# `gogettr` and `truthbrush` are available as Python packages.
#
# Please refer to:
# - [gogettr](https://pypi.org/project/gogettr/)
# - [truthbrush](https://pypi.org/project/truthbrush/)

# %% [markdown]
# ## Installing `gogettr` and `truthbrush` on Anacoda Distribution

# %% [markdown]
# As `gogettr` and `truthbrush` are not available in any of the conda channels, the following procedure should be followed on `Anaconda Prompt` to install it in the required environment, in this case `Env20240401`:

# %% [markdown]
# Note: You have to download and open this Jupyter Notebook on JupyterLab (provided as part of Anaconda Distribution) to visualise the procedure.

# %% [raw]
# (base) C:\Users\eyamr>conda env list
# # conda environments:
# #
# base                  *  C:\Users\eyamr\anaconda3
# Env20240401              C:\Users\eyamr\anaconda3\envs\Env20240401
#
#
# (base) C:\Users\eyamr>conda activate Env20240401
#
# (Env20240401) C:\Users\eyamr>pip3 install gogettr
# <omitted>
#
# (Env20240401) C:\Users\eyamr>pip3 install truthbrush
# <omitted>
#
# (Env20240401) C:\Users\eyamr>pip3 freeze
# <omitted>
# gogettr==0.9.0
# <omitted>
# truthbrush==0.1.8
# <omitted>
#
# (Env20240401) C:\Users\eyamr>conda deactivate
#
# (base) C:\Users\eyamr>

# %% [markdown]
# ## Importing the required libraries

# %%
import gogettr
import truthbrush
import pandas as pd
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.

# %% [markdown]
# ## Extracting posts

# %% [markdown]
# The Python API does not seem to work properly.

# %%
def get_user_posts(username):
    try:
        client = gogettr.PublicClient()
        user_posts = client.user_activity(username=username, type='posts')
        return user_posts
    except Exception as e:
        print(f'Error fetching posts: {e}')
        return []

def save_posts_to_file(posts, filename):
    with open(filename, 'w', encoding='utf-8') as file:
        for post in posts:
            content = post.get('content', '')
            file.write(content + '\n')

if __name__ == '__main__':
    target_username = 'stevebannon'  # Replace with the actual username
    posts = get_user_posts(target_username)
    save_posts_to_file(posts, 'posts.txt')
    print(f"Posts saved to 'posts.txt'")
# Out:
# INFO:gogettr.api:Requesting /u/user/stevebannon/posts (params: {'max': 20, 'dir': 'fwd', 'incl': 'posts|stats|userinfo|shared|liked', 'fp': 'f_uo', 'offset': 0})...
# ...

# %%
def get_user_posts(username):
    try:
        client = gogettr.PublicClient()
        user_posts = client.user_activity(username=username, type='comments')
        return user_posts
    except Exception as e:
        print(f'Error fetching posts: {e}')
        return []

def save_posts_to_file(posts, filename):
    with open(filename, 'w', encoding='utf-8') as file:
        for post in posts:
            content = post.get('content', '')
            file.write(content + '\n')

if __name__ == '__main__':
    target_username = 'stevebannon'  # Replace with the actual username
    posts = get_user_posts(target_username)
    save_posts_to_file(posts, 'comments.txt')
    print(f"Posts saved to 'comments.txt'")
# Out:
# INFO:gogettr.api:Requesting /u/user/stevebannon/posts (params: {'max': 20, 'dir': 'fwd', 'incl': 'posts|stats|userinfo|shared|liked', 'fp': 'f_uc', 'offset': 0})...
# ...

# %% [markdown]
# ## Extracting posts - command line

# %% [markdown]
# The command line API causes the same errors as the Python API when extracting `posts` but delivers consistent JSON files.

# %% [raw]
# (base) C:\Users\eyamr>conda env list
# # conda environments:
# #
# base                  *  C:\Users\eyamr\anaconda3
# Env20240401              C:\Users\eyamr\anaconda3\envs\Env20240401
#
#
# (base) C:\Users\eyamr>conda activate Env20240401
#
# (Env20240401) C:\Users\eyamr>cd Downloads
#
# (Env20240401) C:\Users\eyamr\Downloads>gogettr user stevebannon --type posts > stevebannon_posts.json
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\eyamr\anaconda3\envs\Env20240401\Scripts\gogettr.exe\__main__.py", line 7, in <module>
#   File "C:\Users\eyamr\anaconda3\envs\Env20240401\Lib\site-packages\click\core.py", line 1157, in __call__
#     return self.main(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\eyamr\anaconda3\envs\Env20240401\Lib\site-packages\click\core.py", line 1078, in main
#     rv = self.invoke(ctx)
#          ^^^^^^^^^^^^^^^^
#   File "C:\Users\eyamr\anaconda3\envs\Env20240401\Lib\site-packages\click\core.py", line 1688, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\eyamr\anaconda3\envs\Env20240401\Lib\site-packages\click\core.py", line 1434, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\eyamr\anaconda3\envs\Env20240401\Lib\site-packages\click\core.py", line 783, in invoke
#     return __callback(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\eyamr\anaconda3\envs\Env20240401\Lib\site-packages\gogettr\cli.py", line 41, in user
#     for post in client.user_activity(username.lower(), max=max, until=until, type=type):
#   File "C:\Users\eyamr\anaconda3\envs\Env20240401\Lib\site-packages\gogettr\capabilities\user_activity.py", line 52, in pull
#     post = merge(
#            ^^^^^^
#   File "C:\Users\eyamr\anaconda3\envs\Env20240401\Lib\site-packages\gogettr\utils.py", line 11, in merge
#     for (key, val) in dictionary.items():
#                       ^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'items'
#
# (Env20240401) C:\Users\eyamr\Downloads>gogettr user stevebannon --type comments > stevebannon_comments.json
#
# (Env20240401) C:\Users\eyamr\Downloads>
