# %% [markdown]
# <center>
# <img src="http://corpuslg.org/lael_english/wp-content/uploads/2020/04/lael_50_years_narrow_white.png.400px_300dpi.png" width="300" alt="LAEL 50 years logo">
# <h3>APPLIED LINGUISTICS GRADUATE PROGRAMME (LAEL)</h3>
# </center>
# <hr>

# %% [markdown]
# # Corpus filtering

# %% [markdown]
# ## Requirements
# Talvez se certificar de que todos os tweets tenham pelo menos uma ocorrência desses termos. O twarc output inclui respostas aos tweets que não têm necessariamente os termos de busca, diferentemente do snscrape
#
# Comando para fazer isso:
# grep -E 'vacin|pfizer|astra|coronavac|janssen|jansen|covaxin|antivax|sputnik|dose|vachina|covax' arquivo_com_os_tweets > output.txt
#
# A busca é por strings, então não é preciso usar variações que contêm a mesma string

# %% [markdown]
# ## Importing the required libraries

# %%
import pandas as pd

# %% [markdown]
# ## Loading the corpus into a dataframe

# %%
df_corpus = pd.read_excel('data_single_tweet.xlsx')

# %%
df_corpus.head()
# Out:
#                         file     text_uniq               author_id  \
# 0  vacina202103_n_00106.json  tweet_003773  id_1357768792538021890
# 1  vacina202102_n_00153.json  tweet_004588             id_52548735
# 2  vacina202012_n_00195.json  tweet_004204            id_207142087
# 3  vacina202105_n_00005.json  tweet_011046             id_91268111
# 4  vacina202101_n_00139.json  tweet_002585            id_343415149
#
#                                       text_emojified          created_at  \
# 0  @octopusjh @jdoriajr Cadê a vacinação calça ap... 2021-03-30 23:24:54
# 1  Vacinação Drive Drhu São Paulo Astra Zenica Sã... 2021-02-27 23:03:29
# 2  Lady Gaga ja tomou a vacina, ela está bem, só ... 2020-12-30 23:05:30
# 3  O burro do Burro. #29MForaBolsonaro #charge #c... 2021-05-30 23:58:21
# 4  o arthur especulando uma possivel campanha de ... 2021-01-30 22:47:58
#
#       username                                          tweet_url  retweet
# 0      unknown                                            unknown    False
# 1      unknown                                            unknown    False
# 2  r_camilotti  https://twitter.com/r_camilotti/status/1344419...    False
# 3      unknown                                            unknown    False
# 4       _eunai  https://twitter.com/_eunai/status/135564898014...    False

# %% [markdown]
# ## Filtering the corpus according to the requirements

# %%
df_corpus_filtered = pd.DataFrame(columns = df_corpus.columns)
df_corpus_removed = pd.DataFrame(columns = df_corpus.columns)
for index, row in df_corpus.iterrows():
    if ('vacin' or 'pfizer' or 'astra' or 'coronavac' or 'janssen' or 'jansen' or 'covaxin' or 'antivax' or 'sputnik' or 'dose' or 'vachina' or 'covax') in df_corpus.loc[index, 'text_emojified']:
        df_corpus_filtered = pd.concat([df_corpus_filtered, df_corpus.loc[index].to_frame().T], ignore_index = True)
    else:
        df_corpus_removed = pd.concat([df_corpus_removed, df_corpus.loc[index].to_frame().T], ignore_index = True)

# %% [markdown]
# ### Corpus - filtered

# %%
df_corpus_filtered
# Out:
#                            file     text_uniq               author_id  \
# 0     vacina202103_n_00106.json  tweet_003773  id_1357768792538021890
# 1     vacina202102_n_00153.json  tweet_004588             id_52548735
# 2     vacina202012_n_00195.json  tweet_004204            id_207142087
# 3     vacina202105_n_00005.json  tweet_011046             id_91268111
# 4     vacina202101_n_00139.json  tweet_002585            id_343415149
# ...                         ...           ...                     ...
# 4608  vacina202210_n_00144.json  tweet_005409  id_1266771625191575553
# 4609  vacina202106_n_00010.json  tweet_012901  id_1108882482575884288
# 4610  vacina202108_n_00172.json  tweet_011168   id_920449288794267648
# 4611  vacina202102_n_00151.json  tweet_004621             id_17715048
# 4612  vacina202112_n_00154.json  tweet_000526           id_1613353782
#
#                                          text_emojified          created_at  \
# 0     @octopusjh @jdoriajr Cadê a vacinação calça ap... 2021-03-30 23:24:54
# 1     Vacinação Drive Drhu São Paulo Astra Zenica Sã... 2021-02-27 23:03:29
# 2     Lady Gaga ja tomou a vacina, ela está bem, só ... 2020-12-30 23:05:30
# 3     O burro do Burro. #29MForaBolsonaro #charge #c... 2021-05-30 23:58:21
# 4     o arthur especulando uma possivel campanha de ... 2021-01-30 22:47:58
# ...                                                 ...                 ...
# 4608  da 1a dose da vacina pro tcc cumprido {{Emoji:... 2022-10-28 03:42:16
# 4609  RT @MarcelFrison: Em São Leopoldo, amanhã 30/0... 2021-06-29 23:59:05
# 4610  @LLbrasolin @ChraikseXD @jairbolsonaro cloroqu... 2021-08-30 22:49:50
# 4611  "A retomada econômica passa pela vacinação em ... 2021-02-27 23:00:00
# 4612  A ciência comprova: vacina salva. Quando dispo... 2021-12-30 19:25:59
#
#             username                                          tweet_url  \
# 0            unknown                                            unknown
# 1            unknown                                            unknown
# 2        r_camilotti  https://twitter.com/r_camilotti/status/1344419...
# 3            unknown                                            unknown
# 4             _eunai  https://twitter.com/_eunai/status/135564898014...
# ...              ...                                                ...
# 4608        ellabiru  https://twitter.com/ellabiru/status/1585839337...
# 4609         unknown                                            unknown
# 4610  Eliane33396915  https://twitter.com/Eliane33396915/status/1431...
# 4611            VEJA  https://twitter.com/VEJA/status/13657988685044...
# 4612     AMB_oficial  https://twitter.com/AMB_oficial/status/1476635...
#
#      retweet
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 4608   False
# 4609    True
# 4610   False
# 4611   False
# 4612   False
#
# [4613 rows x 8 columns]

# %% [markdown]
# ### Corpus - removed

# %%
df_corpus_removed
# Out:
#                            file     text_uniq               author_id  \
# 0     vacina202004_n_00132.json  tweet_016725  id_1245166772963217408
# 1     vacina202110_n_00008.json  tweet_010739  id_1321536147705733124
# 2     vacina202106_n_00097.json  tweet_007978            id_395011753
# 3     vacina202010_n_00139.json  tweet_008766             id_56712359
# 4     vacina202109_n_00075.json  tweet_012753   id_984926088789938177
# ...                         ...           ...                     ...
# 2667  vacina202105_n_00078.json  tweet_002957            id_213281125
# 2668  vacina202205_n_00093.json  tweet_014101   id_942389040384442368
# 2669  vacina202101_n_00048.json  tweet_004375           id_1027496948
# 2670  vacina202203_n_00131.json  tweet_010945           id_1306019760
# 2671  vacina202108_n_00124.json  tweet_005397  id_1418948639540514819
#
#                                          text_emojified          created_at  \
# 0     Mc Dricka estralando no som e eu com minha dos... 2020-04-29 18:32:13
# 1     minha dose de serotonina para enfrentar o dia ... 2021-10-30 23:51:43
# 2     O governo pediu 1 real por dose da Covaxin? Va... 2021-06-29 23:50:37
# 3     O professor Aluísio Machado é uma figura inspi... 2020-10-30 20:25:27
# 4     RT @Fruizgomez: Arriban a bodegas de @MinSalud... 2021-09-29 23:23:03
# ...                                                 ...                 ...
# 2667  RT @oiIuiz: Isso tem se repetido muito. E aí, ... 2021-05-30 23:27:59
# 2668  Município inicia aplicação da 3ª dose contra a... 2022-05-30 21:35:02
# 2669  {{Emoji:_Warning}} Brasil: superada a marca de... 2021-01-30 23:34:46
# 2670  baforar cangote: existe dose segura para o uso... 2022-03-30 10:54:51
# 2671  @PretaGil Chegando a minha vez de tomar a segu... 2021-08-30 23:08:50
#
#             username                                          tweet_url  \
# 0            unknown                                            unknown
# 1            unknown                                            unknown
# 2       trajanojorge  https://twitter.com/trajanojorge/status/141002...
# 3            unknown                                            unknown
# 4            unknown                                            unknown
# ...              ...                                                ...
# 2667       luizamasm  https://twitter.com/luizamasm/status/139914559...
# 2668         unknown                                            unknown
# 2669  Belem_Noticias  https://twitter.com/Belem_Noticias/status/1355...
# 2670     falameuanjo  https://twitter.com/falameuanjo/status/1509121...
# 2671         unknown                                            unknown
#
#      retweet
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
# ...      ...
# 2667    True
# 2668   False
# 2669   False
# 2670   False
# 2671   False
#
# [2672 rows x 8 columns]

# %% [markdown]
# ## Writing the results into Excel

# %%
writer_filtered = pd.ExcelWriter('data_single_tweet_filtered.xlsx')
df_corpus_filtered.to_excel(writer_filtered, sheet_name = 'Sheet1')
writer_filtered.close()
writer_removed = pd.ExcelWriter('data_single_tweet_removed.xlsx')
df_corpus_removed.to_excel(writer_removed, sheet_name = 'Sheet1')
writer_removed.close()
